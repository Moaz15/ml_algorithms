# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# most importants are to remember the
#
# filtering (loc)
# merge
# aggregation

# %% [markdown]
# Joins is called merge:
# pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None)

# %%
result = (
    employees
    .groupby(['event_day','emp_id'], as_index=False)
    .agg(total_time=('net_time','sum'))
    .rename(columns={'event_day':'day'})
)

# %%
result = (
    courses
    .groupby(['class'],as_index=False)
    .agg(cnt=('student','count'))
    .query('cnt<=5')
    )
